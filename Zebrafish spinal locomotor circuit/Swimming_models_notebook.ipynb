# %% [markdown]
# # Zebrafish Swimming Models
# ### Below is the block of code to run single coiling models

# %%
# %matplotlib inline
from datetime import datetime

### FIRST, choose which model to run by uncommenting the desired model

# Import connectome package
from Beat_and_glide import *

# Import connectome package
#from Beat_and_glide_with_sigmas import *

# connectome package with commissural excitatory neurons (V0vs), silenced between 5000 and 10000 ms
#from Beat_and_glide_V0v_KO import *

# connectome package with commissural inhibitory neurons (dI6s), silenced between 5000 and 10000 ms
#from Beat_and_glide_dI6_KO import *

# connectome package with ipsilateral inhibitory ascending inhibitory neurons (V1s), silenced between 5000 and 10000 ms
#from Beat_and_glide_V1_KO import *

# connectome package with ipsilateral excitatory descending (V2as), silenced between 5000 and 10000 ms
#from Beat_and_glide_V2a_KO import *

# connectome package with strychnine application between 5000 and 10000 ms
#from Beat_and_glide_strychnine import *

# connectome package with bursting V2a. ***Use the lower set of parameters below***
#from Beat_and_glide_bursting_V2as import *

# connectome package with all neurons firing tonically
#from Beat_and_glide_all_tonic_neurons import *

# connectome package with 30 somites ***Use the lower set of parameters below***
#from Beat_and_glide_30_Somites import *
#from Beat_and_glide_30_Somites_dI6_KO import *

# connectome package with 10 somites ***Use the lower set of parameters below***
#from Beat_and_glide_10_Somites import *

#Declare the duration of the simulation and the discretization time
TIME_END = 20000 
DT = 0.1

# Uncomment the connectome you want to run and comment out the other model

#Beat-and-glide tonic V2a model (baseline model) parameters. Uncomment and comment others as needed
((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a),
   (VLV1, VRV1),(VLMuscle, VRMuscle), Time) = connectome_beat_glide(rand=datetime.datetime.now(), stim0=2.89, sigma=0.0, sigma_LR = 0.1,
                                                     tmax=TIME_END, dt=DT, E_glu=0, E_gly=-70, cv=0.80,
                                                     nMN=15, ndI6=15, nV0v=15, nV2a=15, nV1=15, nMuscle=15, 
                                                     R_str=1.0)

#Beat-and-glide with sigmas. Uncomment and comment others as needed
#((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a), 
#     (VLV1, VRV1),(VLMuscle, VRMuscle), Time) =  connectome_beat_glide(rand=datetime.datetime.now(), stim0=2.89, 
#                                                       sigma_LR = 0.1, sigmaD=0, sigmaL = 0.0, sigmaP = 0.0, sigmaW = 0.0, tmax=TIME_END, 
#                                                       dt=DT, E_glu=0, E_gly=-70, cv=0.80, 
#                                                       nMN=15, ndI6=15, nV0v=15, nV2a=15, nV1=15, nMuscle=15, R_str=1.0) 

# Previous Beat-and-glide tonic V2a model parameters. Uncomment and comment others as needed
#((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a),
#   (VLV1, VRV1),(VLMuscle, VRMuscle), Time) = connectome_beat_glide(rand=datetime.datetime.now(), stim0=2.89, sigma=0.0, sigma_LR = 0.1,
#                                                     tmax=TIME_END, dt=DT, E_glu=0, E_gly=-70, cv=0.80,
#                                                     nMN=15, ndI6=15, nV0v=15, nV2a=15, nV1=15, nMuscle=15, R_str=1.0)
  

#Beat-and-glide bursting V2a model parameters. Uncomment and comment others as needed
#((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a),
#   (VLV1, VRV1),(VLMuscle, VRMuscle), Time) = connectome_beat_glide(rand=datetime.datetime.now(), stim0=3.05, sigma=0.0, sigma_LR = 0.1,
#                                                     tmax=TIME_END, dt=DT, E_glu=0, E_gly=-70, cv=0.80,
#                                                     nMN=15, ndI6=15, nV0v=15, nV2a=15, nV1=15, nMuscle=15, 
#                                                     R_str=1.0)

#Beat-and-glide 30 somites. Uncomment and comment others as needed
#((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a),
#   (VLV1, VRV1),(VLMuscle, VRMuscle), Time) = connectome_beat_glide(rand=datetime.datetime.now(), stim0=2.89, sigma=0.0,
#                                                     tmax=TIME_END, dt=DT, E_glu=0, E_gly=-70, cv=0.80,
#                                                    nMN=30, ndI6=30, nV0v=30, nV2a=30, nV1=30, nMuscle=30,
#                                                    R_str=1.0)

#Beat-and-glide 10 somites. Uncomment and comment others as needed
#((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a),
#   (VLV1, VRV1),(VLMuscle, VRMuscle), Time) = connectome_beat_glide(rand=datetime.datetime.now(), stim0=2.91, sigma=0.0,
#                                                    tmax=TIME_END, dt=DT, E_glu=0, E_gly=-70, cv=0.80,
#                                                    nMN=10, ndI6=10, nV0v=6, nV2a=7, nV1=5, nMuscle=10,
#                                                    R_str=1.0)

#The code below produces a beeping sound af the code has been executed
import winsound
duration = 1000  # milliseconds
freq = 440  # Hz
winsound.Beep(freq, duration)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ebc84579d2ff> in <module>
#      84                                                     tmax=TIME_END, dt=DT, E_glu=0, E_gly=-70, cv=0.80,
#      85                                                     nMN=10, ndI6=10, nV0v=6, nV2a=7, nV1=5, nMuscle=10,
# ---> 86                                                     R_str=1.0)
#      87
#      88 #The code below produces a beeping sound af the code has been executed
#
# ~\OneDrive - University of Ottawa\Tuan Desktop backup\PROJECTS\Modelling Zebrafish swimming CPG\Izhi CPG 2expsyn work for bioRXiv - Annotated\For submission\Beat_and_glide\Beat_and_glide_10_Somites.py in connectome_beat_glide(rand, stim0, sigma, sigma_LR, tmax, dt, E_glu, E_gly, cv, nMN, ndI6, nV0v, nV2a, nV1, nMuscle, R_str)
#     959                 IsynR = sum(RSyn_V2a_V0v[nV0v*l+k,0]*RW_V2a_V0v[l,k] for l in range (0, nV2a)) + sum(RSyn_V1_V0v[nV0v*l+k,0]*RW_V1_V0v[l,k]*R_str for l in range (0, nV1))
#     960
# --> 961             resLV0v[k,:] = L_V0v[k].getNextVal(resLV0v[k,0],resLV0v[k,1],  - sum(LSGap_V0v_V0v[k,:]) + sum(LSGap_V0v_V0v[:,k]) -sum(LSGap_V0v_MN[k,:])  + sum(LSGap_MN_V0v[:,k]) + IsynL)
#     962             VLV0v[k,t] = resLV0v[k,0]
#     963             resRV0v[k,:] = R_V0v[k].getNextVal(resRV0v[k,0],resRV0v[k,1],  - sum(RSGap_V0v_V0v[k,:]) + sum(RSGap_V0v_V0v[:,k]) -sum(RSGap_V0v_MN[k,:])  + sum(RSGap_MN_V0v[:,k]) + IsynR)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Once the connectome has compiled you can plot traces of all neurons

# %%
# %matplotlib inline

#color maps for left and right traces
cmapL = matplotlib.cm.get_cmap('Blues')
cmapR = matplotlib.cm.get_cmap('Reds')
    
#decalre figure
fig, ax = plt.subplots(6,1, sharex=True, figsize=(15, 15)) 

# just adding fake plot for the legend
ax[0].plot([0], [0], c=cmapL(0.5))
ax[0].plot([0], [0], c=cmapR(0.5))

#number of MNs
nMN = len(VLMN[:,0])
# plotting motoneuron traces
#for k in range(9,10):
for k in range (0, nMN):
    ax[0].plot(Time, VLMN[k,:], c=cmapL((k+1)/nMN)) # adding a color gradient, lighter color -> rostrally located
    ax[0].plot(Time, VRMN[k,:], c=cmapR((k+1)/nMN))
ax[0].legend(['left_MN','right_MN'], loc='upper right') #legend

#y-axis limit
lower_y = -80
upper_y = 20
for i in range (0,5):
    ax[i].set_ylabel('Membrane potential (mV)') #y-axis title for most plots
    ax[i].set_ylim([lower_y, upper_y])#y-axis limits for most plots

ax[5].set_ylabel('Muscle activity') #y-axis limits for muscle plot
ax[5].set_ylim([-1,6]) #y-axis limits for muscle plot

# plotting dI6 traces. Same set-up as MN plot
ndI6 = len(VLdI6[:,0])
cmapL = matplotlib.cm.get_cmap('Blues')
cmapR = matplotlib.cm.get_cmap('Reds')
ax[1].plot([0], [0], c=cmapL(0.5))
ax[1].plot([0], [0], c=cmapR(0.5))    

for k in range (0, ndI6):
    ax[1].plot(Time, VLdI6[k,:], c=cmapL((k+1)/ndI6)) 
    ax[1].plot(Time, VRdI6[k,:], c=cmapR((k+1)/ndI6))
ax[1].legend(['left_dI6','right_dI6'], loc='upper right')

try:
    VLV0v
except NameError:
    print("unidentified")
else:
    # plotting V0v traces. Same set-up as MN plot
    nV0v = len(VLV0v[:,0])
    cmapL = matplotlib.cm.get_cmap('Blues')
    cmapR = matplotlib.cm.get_cmap('Reds')
    ax[2].plot([0], [0], c=cmapL(0.5))
    ax[2].plot([0], [0], c=cmapR(0.5))    
    
    #for k in range(9,10):
    for k in range (0, nV0v):
        ax[2].plot(Time, VLV0v[k,:], c=cmapL((k+1)/nV0v)) 
        ax[2].plot(Time, VRV0v[k,:], c=cmapR((k+1)/nV0v))
    ax[2].legend(['left_V0v','right_V0v'], loc='upper right')

try:
    VLV2a
except NameError:
    print("unidentified")
else: 
    # plotting V2a traces. Same set-up as MN plot
    nV2a = len(VLV2a[:,0])
    cmapL = matplotlib.cm.get_cmap('Blues')
    cmapR = matplotlib.cm.get_cmap('Reds')
    ax[3].plot([0], [0], c=cmapL(0.5))
    ax[3].plot([0], [0], c=cmapR(0.5))    

    for k in range (0, nV2a):
        ax[3].plot(Time, VLV2a[k,:], c=cmapL((k+1)/nV2a)) 
        ax[3].plot(Time, VRV2a[k,:], c=cmapR((k+1)/nV2a))
    ax[3].legend(['left_V2a','right_V2a'], loc='upper right')

# plotting V1 traces. Same set-up as MN plot
try:
    VLV1
except NameError:
    print("unidentified")
else:
    nV1 = len(VLV1[:,0])
    cmapL = matplotlib.cm.get_cmap('Blues')
    cmapR = matplotlib.cm.get_cmap('Reds')
    ax[4].plot([0], [0], c=cmapL(0.5))
    ax[4].plot([0], [0], c=cmapR(0.5))    

    for k in range (0, nV1):
        ax[4].plot(Time, VLV1[k,:], c=cmapL((k+1)/nV1)) 
        ax[4].plot(Time, VRV1[k,:], c=cmapR((k+1)/nV1))
    ax[4].legend(['left_V1','right_V1'], loc='upper right')
    
nMuscle = len(VLMuscle[:,0])
cmapL = matplotlib.cm.get_cmap('Blues')
cmapR = matplotlib.cm.get_cmap('Reds')
ax[5].plot([0], [0], c=cmapL(0.5))
ax[5].plot([0], [0], c=cmapR(0.5))    

#Plot muscle traces. Same set-up as MN plot
for k in range (0, nMuscle): 
    ax[5].plot(Time, VLMuscle[k,:], c=cmapL((k+1)/nMuscle)) 
    ax[5].plot(Time, VRMuscle[k,:], c=cmapR((k+1)/nMuscle))
ax[5].legend(['left_Muscle','right_Muscle'], loc='upper right')
    

plt.xlabel('Time (ms)') #x-axis label
plt.xlim([0, TIME_END]) #x-axis limit

plt.show()

# %% [markdown]
# ### The code below is to save the simulation data into a .csv file that can be read into the notebook at a later time

# %%
# Import pandas for data saving
import pandas as pd

#cell names
cell_names = ['MN', 'dI6','V0v', 'V2a', 'V1', 'Muscle']

#calculate the number of cell in each population
nMN = len(VLMN[:,0])
ndI6 = len(VLdI6[:,0])
nV0v = len(VLV0v[:,0])
nV2a = len(VLV2a[:,0])
nV1 = len(VLV1[:,0])
nMuscle = len(VLMuscle[:,0])
num_cells = [nMN, ndI6, nV0v, nV2a, nV1, nMuscle]

#List left and right traces
Vdata_list =[VLMN, VRMN, VLdI6, VRdI6, VLV0v, VRV0v, VLV2a, VRV2a, VLV1, VRV1, VLMuscle, VRMuscle]

#Sim_data is the dataframe that will hold all the traces
Sim_data = pd.DataFrame(index=Time)

for i in range(0, len(cell_names)):
    for j in range(0, num_cells[i]):
        header_name = 'Left_' + cell_names[i] + str(j)
        #Sim_data = pd.DataFrame(header_name, data_list[i,j])
        Sim_data.insert(len(Sim_data.columns), column = header_name, value = Vdata_list[i*2][j]) # insert a new column
    for k in range(0, num_cells[i]):
        header_name = 'Right_' + cell_names[i] + str(k)
        Sim_data.insert(len(Sim_data.columns), column = header_name, value = Vdata_list[i*2+1][k]) # insert a new column

#Convert Sim_data into a .csv file. CHANGE FILE NAME as needed
Sim_data.to_csv("Beat_and_Glide_30_somites_dI6_KO_20000ms.csv")

# %% [markdown]
# ### The code below allows you to import data from a previously run simulation of a BEAT AND GLIDE MODEL that was saved into .csv

# %%
# Import pandas for data saving
import pandas as pd
import numpy as np
from pylab import *
from Analysis_tools import *

#Read .csv file into cell traces
read_data = pd.read_csv("Beat_and_Glide_10000ms.csv")
read_data

data_top = list(read_data.columns.values.tolist())
data_top

MN_index = []
dI6_index = [] 
V0v_index = []  
V2a_index = [] 
V1_index = []
Muscle_index = []

for i in range(0, len(data_top)):
    if (data_top[i].find('MN') != -1):
        MN_index.append(int(data_top[i][data_top[i].find('MN')+2:data_top[i].find('MN')+4]))
        nMN = max(MN_index) + 1
    if (data_top[i].find('dI6') != -1):
        dI6_index.append(int(data_top[i][data_top[i].find('dI6')+3:data_top[i].find('dI6')+5]))
        ndI6 = max(dI6_index) + 1
    if (data_top[i].find('V0v') != -1):
        V0v_index.append(int(data_top[i][data_top[i].find('V0v')+3:data_top[i].find('V0v')+5]))
        nV0v = max(V0v_index) + 1
    if (data_top[i].find('V2a') != -1):
        V2a_index.append(int(data_top[i][data_top[i].find('V2a')+3:data_top[i].find('V2a')+5]))
        nV2a = max(V2a_index) + 1
    if (data_top[i].find('V1') != -1):
        V1_index.append(int(data_top[i][data_top[i].find('V1')+2:data_top[i].find('V1')+4]))
        nV1 = max(V1_index) + 1
    if (data_top[i].find('Muscle') != -1):
        Muscle_index.append(int(data_top[i][data_top[i].find('Muscle')+6:data_top[i].find('Muscle')+8]))
        nMuscle = max(Muscle_index) + 1
        
read_sim = np.ascontiguousarray(read_data)
read_sim = np.transpose(read_sim)
read_sim
Time = read_sim[0]
next_start = 1
next_end = next_start + nMN
VLMN = read_sim[1:next_end]
next_start = next_end
next_end = next_start + nMN
VRMN = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + ndI6
VLdI6 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + ndI6
VRdI6 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV0v
VLV0v = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV0v
VRV0v = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV2a
VLV2a = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV2a
VRV2a = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV1
VLV1 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV1
VRV1 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nMuscle
VLMuscle = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nMuscle
VRMuscle = read_sim[next_start:next_end]
TIME_END = Time[-1]
TIME_END

nMN, ndI6, nV0v, nV2a, nV1, nMuscle #check the number of cells in each population to ensure that the read-in worked
# Out:
# (15, 15, 15, 15, 15, 15)

# %% [markdown]
# The following command plots a heatmaps of the local body angles vs time matrix for all muscle segments and the FFT of the previous matrix

# %%
angle, FFT = Heatmap(VLMuscle, VRMuscle, dt=0.1, vmin_=-0.1, vmax_=0.1, ymin=0, ymax=10000)

# %% [markdown]
# The block below calculates the time delay per somite

# %%
Caudal_index = 14
Rostral_index = 10

DT = 0.1

#Calculate cross correlation between muscle output in two somites of the same side of the boy
res = Xcorr(VRMuscle[Caudal_index,:],VRMuscle[Rostral_index,:])

fig, ax = plt.subplots() 
right_side = ax.spines["right"]
top_side = ax.spines["top"]
right_side.set_visible(False)
top_side.set_visible(False)

plt.plot(Time[:int(TIME_END/DT)], res, '-k')
plt.xlabel('Time delay: Tau(ms)')
plt.ylabel('Crosscorelation')
plt.title('Somite ' + str(Caudal_index) + ' VS somite ' + str(Rostral_index))
plt.xlim([0,200])
plt.show()

print('____________')
print('Time delay per somite (ms) =')
print(Time[np.where(res==np.max(res))[0]] / (Caudal_index - Rostral_index))

# %% [markdown]
# The block below performs an autocorrelation at somite somite_index.  The peaks can be used to estimate tail beat frequency

# %%
DT = 0.1
TIME_END = len(Time)*DT
for i in range (0, 15):
    #Declare the somite at which the autocorrelation will be made
    somite_index = i
    #Autocorrelation at somite_index
    res = Xcorr(VRMuscle[somite_index,:],VRMuscle[somite_index,:])

    fig, ax = plt.subplots() 
    right_side = ax.spines["right"]
    top_side = ax.spines["top"]
    right_side.set_visible(False)
    top_side.set_visible(False)

    plt.plot(Time[:int(TIME_END/DT)], res, '-k')
    plt.xlabel('Time delay: Tau(ms)')
    plt.ylabel('Autocorelation')
    plt.title('Somite ' + str(somite_index))
    plt.xlim([0,200])
    plt.show()

# %% [markdown]
# Analyze left-right coordination using cross-correlation

# %%
fig, ax = plt.subplots(1,3, sharex=True, figsize=(15, 5)) 

#Calculate Left-right cross-correlation between somites 0, 5, and 10.  If this is changed, the number of subplots
# will also have to be changed when creating the figure
for Somite_index in range (0, nMuscle, 5):
    #Calculate the left-right coordination between 5,000 and 10,000 ms. This can ge changed as needed
    res = Xcorr_LR(VLMuscle[Somite_index,50000:100000],VRMuscle[Somite_index,50000:100000])

    right_side = ax[int(Somite_index/5)].spines["right"]
    top_side = ax[int(Somite_index/5)].spines["top"]
    right_side.set_visible(False)
    top_side.set_visible(False)

    ax[int(Somite_index/5)].title.set_text('Right Somite ' + str(Somite_index) + ' VS Left somite ' + str(Somite_index))
    
    #New_time contains the time delays from -Time to Time
    New_time = Time.tolist()+(-Time).tolist()
    order = np.argsort(New_time)
    New_time= np.asarray(New_time)[order] 

    ax[int(Somite_index/5)].plot(New_time[100201:200200], res, '-k') 

plt.xlabel('Time delay: Tau(ms)')
plt.ylabel('Crosscorelation')
plt.xlim([-50,50])
plt.show()

# %% [markdown]
# Functions used to detect start and ends of swimming episodes

# %%
#This function smoothens the input y
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

#This function takes the VL and VRMuscle traces, smoothes them, and then based on a threshold, right now of 0.5
# calculates the start and end times of swimming epidoses
def detect_event(VLMuscle, VRMuscle):
    
    X = np.sum(VLMuscle, axis=0) + np.sum(VRMuscle, axis=0)
    X = smooth(X, 500) #convolve with a step 50 ms wide
    Xt = Time[np.where(X > 0.5)]
    
    plt.plot(Time, X)
    plt.axhline(y=0.5, ls='--', c='r')

    end = Xt[[Xt[i+1] - Xt[i] > 0.2 for i in range(len(Xt)-1)]+[True]]
    start = Xt[[True]+[Xt[i+1] - Xt[i] > 0.2 for i in range(len(Xt)-1)]]
    duration = end - start
    
    return start, end, duration

# %% [markdown]
# Analyze swimming episode start and end times as well as durations using functions above

# %%
from Analysis_tools import *
Threshold = 0.5
Start, End, Duration = detect_event(VLMuscle, VRMuscle, Time, Threshold)
print("Episode start and end times")
for s,e in zip(Start,End):
    print(s,e)
    plt.plot(Time[int(s*10):int(e*10)], VLMuscle[9,int(s*10):int(e*10)])
plt.show()
print("Episode durations")
Duration

# %% [markdown]
# # Animated plot
# The animations work though the saving of the animations to a file doesn't work yet

# %%
# %matplotlib notebook
# %matplotlib notebook

mywriter = animation.FFMpegWriter()
# Declare the number of somites
nMuscle = 15
# Declare the discretization time
dt = 0.1
# Calculate the number of time points
nmax = int(TIME_END/dt)
ani = angles_(Time,nMuscle,nmax,VRMuscle,VLMuscle,dt)
# Out:
# <img src="data:image/png;base64,..." width="568.8888888888889">

# %%
ani.save("Beat_and_Glide_strychnine.mp4", writer=mywriter)#, fps=30)#, extra_args=['-vcodec', 'libx264'])

# %% [markdown]
# ## Testing proper combination of R, C and Motoneuron to muscle weight for kinematics of beat and glide swimming

# %%
# %matplotlib notebook
# %matplotlib notebook
from Izhikevich_class import*
from Analysis_tools import *
import pandas as pd
import numpy as np
from Recalc_muscle_output import * 

### NOW PLOTTING NEURON ACTIVITY DURING SWIMMING SIMULATION ###
# This file was used to make the figure for all of the neuron traces during a typical double coil
read_data = pd.read_csv("Beat_and_Glide_baseline_model_10000ms_run.csv")

data_top = list(read_data.columns.values.tolist())
data_top

MN_index = []
dI6_index = [] 
V0v_index = []  
V2a_index = [] 
V1_index = []
Muscle_index = []

for i in range(0, len(data_top)):
    if (data_top[i].find('MN') != -1):
        MN_index.append(int(data_top[i][data_top[i].find('MN')+2:data_top[i].find('MN')+4]))
        nMN = max(MN_index) + 1
    if (data_top[i].find('dI6') != -1):
        dI6_index.append(int(data_top[i][data_top[i].find('dI6')+3:data_top[i].find('dI6')+5]))
        ndI6 = max(dI6_index) + 1
    if (data_top[i].find('V0v') != -1):
        V0v_index.append(int(data_top[i][data_top[i].find('V0v')+3:data_top[i].find('V0v')+5]))
        nV0v = max(V0v_index) + 1
    if (data_top[i].find('V2a') != -1):
        V2a_index.append(int(data_top[i][data_top[i].find('V2a')+3:data_top[i].find('V2a')+5]))
        nV2a = max(V2a_index) + 1
    if (data_top[i].find('V1') != -1):
        V1_index.append(int(data_top[i][data_top[i].find('V1')+2:data_top[i].find('V1')+4]))
        nV1 = max(V1_index) + 1
    if (data_top[i].find('Muscle') != -1):
        Muscle_index.append(int(data_top[i][data_top[i].find('Muscle')+6:data_top[i].find('Muscle')+8]))
        nMuscle = max(Muscle_index) + 1
        
read_sim = np.ascontiguousarray(read_data)
read_sim = np.transpose(read_sim)
read_sim
Time = read_sim[0]
next_start = 1
next_end = next_start + nMN
VLMN = read_sim[1:next_end]
next_start = next_end
next_end = next_start + nMN
VRMN = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + ndI6
VLdI6 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + ndI6
VRdI6 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV0v
VLV0v = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV0v
VRV0v = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV2a
VLV2a = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV2a
VRV2a = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV1
VLV1 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nV1
VRV1 = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nMuscle
VLMuscle = read_sim[next_start:next_end]
next_start = next_end
next_end = next_start + nMuscle
VRMuscle = read_sim[next_start:next_end]
TIME_END = Time[-1]
TIME_END

Weights = [0.025 + i*0.025 for i in range(0, 8)]

for R_val in range(1, 10, 2):
    for C_val in range(11, 20, 2):
        for Weight in Weights:

            VLMuscle, VRMuscle = recalc_muscle_ouptut(VLMN, VRMN, Time, dt = 0.1, nMN = 15, nMuscle = 15, R = R_val, C = C_val, weight_MN_Muscle = Weight)

            # %matplotlib notebook

            mywriter = animation.FFMpegWriter()
            nMuscle = 15
            dt = 0.1
            nmax = int(TIME_END/dt)
            ani = angles_(Time[0:nmax],nMuscle,nmax,VRMuscle,VLMuscle,dt)
            
            filename = './BnG_R_' + str(R_val)+ 'C_' + str(C_val)+ 'weight_0pt0' + str(int(Weight*1000)) + '.mp4'
            ani.save(filename)

# %% [markdown]
# Code to simulate 10 runs of the base model of beat_and_glide

# %%
import pandas as pd
from Beat_and_glide_with_sigmas import *
from datetime import datetime

TIME_END = 10000 

DT = 0.1

for run in range(1, 10, 1):
    # %matplotlib inline
    
    ((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a), 
         (VLV1, VRV1),(VLMuscle, VRMuscle), Time) =  connectome_beat_glide(rand=datetime.now(), stim0=2.89, 
                                                           sigma_LR = 0.1, sigmaD=0, sigmaL = 0.0, sigmaP = 0.0, sigmaW = 0.0, tmax=TIME_END, 
                                                           dt=DT, E_glu=0, E_gly=-70, cv=0.80, 
                                                           nMN=15, ndI6=15, nV0v=15, nV2a=15, nV1=15, nMuscle=15, R_str=1.0) 

    import pandas as pd

    cell_names = ['MN', 'dI6','V0v', 'V2a', 'V1', 'Muscle']

    nMN = len(VLMN[:,0])
    ndI6 = len(VLdI6[:,0])
    nV0v = len(VLV0v[:,0])
    nV2a = len(VLV2a[:,0])
    nV1 = len(VLV1[:,0])
    nMuscle = len(VLMuscle[:,0])
    num_cells = [nMN, ndI6, nV0v, nV2a, nV1, nMuscle]

    Vdata_list =[VLMN, VRMN, VLdI6, VRdI6, VLV0v, VRV0v, VLV2a, VRV2a, VLV1, VRV1, VLMuscle, VRMuscle]

    Sim_data = pd.DataFrame(index=Time)

    for i in range(0, len(cell_names)):
        for j in range(0, num_cells[i]):
            header_name = 'Left_' + cell_names[i] + str(j)
            #Sim_data = pd.DataFrame(header_name, data_list[i,j])
            Sim_data.insert(len(Sim_data.columns), column = header_name, value = Vdata_list[i*2][j]) # insert a new column
        for k in range(0, num_cells[i]):
            header_name = 'Right_' + cell_names[i] + str(k)
            Sim_data.insert(len(Sim_data.columns), column = header_name, value = Vdata_list[i*2+1][k]) # insert a new column

    Sim_data.to_csv("Beat_and_Glide_base_model_" + str(run) + ".csv")

 
    #The code below can save parameters for each neuron
    '''
    Parameter_index = ['a', 'b','c','d', 'vmax', 'vr', 'vt', 'k','C']
    
    Sim_parameters = pd.DataFrame({'L_MN0' : L_MN[0].return_parameters(), 'L_MN1' : L_MN[1].return_parameters(), 'L_MN2' : L_MN[2].return_parameters(),
                                   'L_MN3' : L_MN[3].return_parameters(), 'L_MN4' : L_MN[4].return_parameters(), 'L_MN5' : L_MN[5].return_parameters(), 
                                   'L_MN6' : L_MN[6].return_parameters(), 'L_MN7' : L_MN[7].return_parameters(), 'L_MN8' : L_MN[8].return_parameters(),
                                   'L_MN9' : L_MN[9].return_parameters(), 'L_MN10' : L_MN[10].return_parameters(), 'L_MN11' : L_MN[11].return_parameters(),
                                   'L_MN12' : L_MN[12].return_parameters(), 'L_MN13' : L_MN[13].return_parameters(), 'L_MN14' : L_MN[14].return_parameters(),
                                   'R_MN0' : R_MN[0].return_parameters(), 'R_MN1' : R_MN[1].return_parameters(), 'R_MN2' : R_MN[2].return_parameters(),
                                   'R_MN3' : R_MN[3].return_parameters(), 'R_MN4' : R_MN[4].return_parameters(), 'R_MN5' : R_MN[5].return_parameters(),
                                   'R_MN6' : R_MN[6].return_parameters(), 'R_MN7' : R_MN[7].return_parameters(), 'R_MN8' : R_MN[8].return_parameters(),
                                   'R_MN9' : R_MN[9].return_parameters(), 'R_MN10' : R_MN[10].return_parameters(), 'R_MN11' : R_MN[11].return_parameters(),
                                   'R_MN12' : R_MN[12].return_parameters(), 'R_MN13' : R_MN[13].return_parameters(), 'R_MN14' : R_MN[14].return_parameters(),
                                   'L_dI60' : L_dI6[0].return_parameters(), 'L_dI61' : L_dI6[1].return_parameters(), 'L_dI62' : L_dI6[2].return_parameters(),
                                   'L_dI63' : L_dI6[3].return_parameters(), 'L_dI64' : L_dI6[4].return_parameters(), 'L_dI65' : L_dI6[5].return_parameters(), 
                                   'L_dI66' : L_dI6[6].return_parameters(), 'L_dI67' : L_dI6[7].return_parameters(), 'L_dI68' : L_dI6[8].return_parameters(),
                                   'L_dI69' : L_dI6[9].return_parameters(), 'L_dI610' : L_dI6[10].return_parameters(), 'L_dI611' : L_dI6[11].return_parameters(),
                                   'L_dI612' : L_dI6[12].return_parameters(), 'L_dI613' : L_dI6[13].return_parameters(), 'L_dI614' : L_dI6[14].return_parameters(),
                                   'R_dI60' : R_dI6[0].return_parameters(), 'R_dI61' : R_dI6[1].return_parameters(), 'R_dI62' : R_dI6[2].return_parameters(),
                                   'R_dI63' : R_dI6[3].return_parameters(), 'R_dI64' : R_dI6[4].return_parameters(), 'R_dI65' : R_dI6[5].return_parameters(),
                                   'R_dI66' : R_dI6[6].return_parameters(), 'R_dI67' : R_dI6[7].return_parameters(), 'R_dI68' : R_dI6[8].return_parameters(),
                                   'R_dI69' : R_dI6[9].return_parameters(), 'R_dI610' : R_dI6[10].return_parameters(), 'R_dI611' : R_dI6[11].return_parameters(),
                                   'R_dI612' : R_dI6[12].return_parameters(), 'R_dI613' : R_dI6[13].return_parameters(), 'R_dI614' : R_dI6[14].return_parameters(),
                                   'L_V0v0' : L_V0v[0].return_parameters(), 'L_V0v1' : L_V0v[1].return_parameters(), 'L_V0v2' : L_V0v[2].return_parameters(),
                                   'L_V0v3' : L_V0v[3].return_parameters(), 'L_V0v4' : L_V0v[4].return_parameters(), 'L_V0v5' : L_V0v[5].return_parameters(), 
                                   'L_V0v6' : L_V0v[6].return_parameters(), 'L_V0v7' : L_V0v[7].return_parameters(), 'L_V0v8' : L_V0v[8].return_parameters(),
                                   'L_V0v9' : L_V0v[9].return_parameters(), 'L_V0v10' : L_V0v[10].return_parameters(), 'R_V0v0' : R_V0v[0].return_parameters(),
                                   'R_V0v1' : R_V0v[1].return_parameters(), 'R_V0v2' : R_V0v[2].return_parameters(),'R_V0v3' : R_V0v[3].return_parameters(), 
                                   'R_V0v4' : R_V0v[4].return_parameters(), 'R_V0v5' : R_V0v[5].return_parameters(), 'R_V0v6' : R_V0v[6].return_parameters(), 
                                   'R_V0v7' : R_V0v[7].return_parameters(), 'R_V0v8' : R_V0v[8].return_parameters(),'R_V0v9' : R_V0v[9].return_parameters(),
                                   'R_V0v10' : R_V0v[10].return_parameters(),'L_V2a0' : L_V2a[0].return_parameters(), 'L_V2a1' : L_V2a[1].return_parameters(),
                                   'L_V2a2' : L_V2a[2].return_parameters(),'L_V2a3' : L_V2a[3].return_parameters(), 'L_V2a4' : L_V2a[4].return_parameters(), 
                                   'L_V2a5' : L_V2a[5].return_parameters(), 'L_V2a6' : L_V2a[6].return_parameters(), 'L_V2a7' : L_V2a[7].return_parameters(), 
                                   'L_V2a8' : L_V2a[8].return_parameters(),'L_V2a9' : L_V2a[9].return_parameters(), 'L_V2a10' : L_V2a[10].return_parameters(),
                                   'L_V2a11' : L_V2a[11].return_parameters(),'R_V2a0' : R_V2a[0].return_parameters(), 'R_V2a1' : R_V2a[1].return_parameters(),
                                   'R_V2a2' : R_V2a[2].return_parameters(),'R_V2a3' : R_V2a[3].return_parameters(), 'R_V2a4' : R_V2a[4].return_parameters(),
                                   'R_V2a5' : R_V2a[5].return_parameters(), 'R_V2a6' : R_V2a[6].return_parameters(), 'R_V2a7' : R_V2a[7].return_parameters(),
                                   'R_V2a8' : R_V2a[8].return_parameters(),'R_V2a9' : R_V2a[9].return_parameters(), 'R_V2a10' : R_V2a[10].return_parameters(),
                                   'R_V2a11' : R_V2a[11].return_parameters(),'L_V10' : L_V1[0].return_parameters(), 'L_V11' : L_V1[1].return_parameters(),
                                   'L_V12' : L_V1[2].return_parameters(),'L_V13' : L_V1[3].return_parameters(), 'L_V14' : L_V1[4].return_parameters(),
                                   'L_V15' : L_V1[5].return_parameters(), 'L_V16' : L_V1[6].return_parameters(), 'L_V17' : L_V1[7].return_parameters(),
                                   'L_V18' : L_V1[8].return_parameters(),'L_V19' : L_V1[9].return_parameters(), 'R_V10' : R_V1[0].return_parameters(), 
                                   'R_V11' : R_V1[1].return_parameters(), 'R_V12' : R_V1[2].return_parameters(),'R_V13' : R_V1[3].return_parameters(), 
                                   'R_V14' : R_V1[4].return_parameters(), 'R_V15' : R_V1[5].return_parameters(), 'R_V16' : R_V1[6].return_parameters(),
                                   'R_V17' : R_V1[7].return_parameters(), 'R_V18' : R_V1[8].return_parameters(),'R_V19' : R_V1[9].return_parameters()},
                                      index=Parameter_index)
    
    Sim_parameters.to_csv("Beat_and_glide_Sim_data_Sensitivity_testing_SigmaL_0pt50_" + str(p) + "_parameters.csv")
    '''
    
    # %matplotlib notebook
    # %matplotlib notebook

    mywriter = animation.FFMpegWriter()
    nMuscle = 15
    dt = 0.1
    nmax = int(TIME_END/dt)
    ani = angles_(Time,nMuscle,nmax,VRMuscle,VLMuscle,dt)
    
    ani.save("./Beat_and_glide_base_model_" + str(run) + ".mp4")#, fps=30)#, extra_args=['-vcodec', 'libx264'])

# %% [markdown]
# Code to run sensitivty analysis for E_REV

# %%
import pandas as pd
from Beat_and_glide import *
from datetime import datetime

TIME_END = 10000 # 10000 

DT = 0.1

#Choose value of E_rev glycine
E_REV = -62

for p in range (0, 10): 
    # %matplotlib inline
    
    ((VLMN, VRMN), (VLdI6, VRdI6), (VLV0v, VRV0v), (VLV2a, VRV2a),
       (VLV1, VRV1),(VLMuscle, VRMuscle), Time) = connectome_beat_glide(rand=datetime.now(), stim0=2.89, sigma=0.0, sigma_LR = 0.1,
                                                         tmax=TIME_END, dt=DT, E_glu=0, E_gly=E_REV, cv=0.80,
                                                         nMN=15, ndI6=15, nV0v=15, nV2a=15, nV1=15, nMuscle=15, 
                                                         R_str=1.0)    


    cell_names = ['MN', 'dI6','V0v', 'V2a', 'V1', 'Muscle']

    nMN = len(VLMN[:,0])
    ndI6 = len(VLdI6[:,0])
    nV0v = len(VLV0v[:,0])
    nV2a = len(VLV2a[:,0])
    nV1 = len(VLV1[:,0])
    nMuscle = len(VLMuscle[:,0])
    num_cells = [nMN, ndI6, nV0v, nV2a, nV1, nMuscle]

    Vdata_list =[VLMN, VRMN, VLdI6, VRdI6, VLV0v, VRV0v, VLV2a, VRV2a, VLV1, VRV1, VLMuscle, VRMuscle]

    Sim_data = pd.DataFrame(index=Time)

    for i in range(0, len(cell_names)):
        for j in range(0, num_cells[i]):
            header_name = 'Left_' + cell_names[i] + str(j)
            #Sim_data = pd.DataFrame(header_name, data_list[i,j])
            Sim_data.insert(len(Sim_data.columns), column = header_name, value = Vdata_list[i*2][j]) # insert a new column
        for k in range(0, num_cells[i]):
            header_name = 'Right_' + cell_names[i] + str(k)
            Sim_data.insert(len(Sim_data.columns), column = header_name, value = Vdata_list[i*2+1][k]) # insert a new column
    
    #Save to a data file. Change the name based upon your preference
    Sim_data.to_csv("Beat_and_glide_Sim_data_Sensitivity_testing_E_GLY_" + str(E_REV) + "_" + str(p) + ".csv")

    
    # %matplotlib notebook
    # %matplotlib notebook

    mywriter = animation.FFMpegWriter()
    nMuscle = 10
    dt = 0.1
    nmax = int(TIME_END/dt)
    ani = angles_(Time,nMuscle,nmax,VRMuscle,VLMuscle,dt)
    
    ani.save("./Beat_and_glide_Sim_data_Sensitivity_testing_E_GLY_" + str(E_REV) + "_" + str(p) + ".mp4")#, fps=30)#, extra_args=['-vcodec', 'libx264'])
